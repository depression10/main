# %% [markdown]
# <a href="https://colab.research.google.com/github/depression10/main/blob/main/hama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\033[31mMohammed Tofiq\033[0m")
# Out:
# Mohammed Tofiq

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('/content/drive/MyDrive/Student Depression Dataset.csv')

# %%
mydata.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
# 5  33    Male  29.0           Pune    Student                2.0
# 6  52    Male  30.0          Thane    Student                3.0
# 7  56  Female  30.0        Chennai    Student                2.0
# 8  59    Male  28.0         Nagpur    Student                3.0
# 9  62    Male  31.0         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# ...

# %%
np.mean(mydata['Age'])
# Out:
# np.float64(25.82230027597577)

# %%
np.median(mydata['Age'])
# Out:
# np.float64(25.0)

# %%
np.var(mydata['Age'])**(1/2)
# Out:
# 4.905599535742001

# %%
Q1 = mydata["Age"].quantile(0.25)  # 25th percentile
Q3 = mydata["Age"].quantile(0.75)  # 75th percentile
IQR = Q3 - Q1
print("Interquartile Range (IQR) of area:", IQR)
# Out:
# Interquartile Range (IQR) of area: 9.0

# %%
mydata.hist(figsize=(30,40), color='green')
plt.show()

# %%
sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>
